# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n = 1000000

data = np.random.standard_normal(n)

def plot(d):
    h, _ = np.histogram(d, 100, density=True)
    plt.plot(np.linspace(d.min(), d.max(), len(h)), h)

plot(data)

shifted = 0.5 * data + 0.5

plot(shifted)
